# %% [markdown]
# # Análisis y Predicción de Calidad del Vino
#
# Este notebook implementa un modelo de árbol de decisión para predecir la calidad del vino basado en sus características fisicoquímicas.
#
# ## Contenido:
# 1. Carga y preprocesamiento de datos
# 2. Análisis exploratorio (EDA)
# 3. Preparación de características
# 4. Entrenamiento del modelo
# 5. Evaluación y métricas
# 6. Visualización del árbol

# %%
# Importar librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# Configuración de visualización
# %matplotlib inline
plt.style.use('seaborn-v0_8')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 1. Carga y Preprocesamiento de Datos

# %%
# Cargar dataset
df = pd.read_csv('../datasets/winequality-red.csv', sep=';')

print("Dimensiones del dataset:", df.shape)
print("\nPrimeras filas:")
display(df.head())

print("\nInformación del dataset:")
display(df.info())

# %% [markdown]
# ## 2. Análisis Exploratorio de Datos (EDA)

# %%
# Código del análisis exploratorio (mismo que en exploratory_analysis.py)
# ... (incluir todo el código de visualización)

# %% [markdown]
# ## 3. Preparación de Características

# %%
# Separar features y target
X = df.drop('quality', axis=1)
y = df['quality']

# Escalar características
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split de datos
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 4. Entrenamiento del Modelo

# %%
# Entrenar modelo
model = DecisionTreeClassifier(random_state=42, max_depth=5)
model.fit(X_train, y_train)

print("Modelo entrenado exitosamente!")

# %% [markdown]
# ## 5. Evaluación y Métricas

# %%
# Código de evaluación (mismo que en model_training.py)
# ... (incluir todo el código de evaluación y visualización)

# %% [markdown]
# ## 6. Guardar el Modelo

# %%
# Guardar modelo y scaler
joblib.dump(model, 'wine_quality_model.joblib')
joblib.dump(scaler, 'wine_quality_scaler.joblib')
print("Modelo guardado exitosamente!")
